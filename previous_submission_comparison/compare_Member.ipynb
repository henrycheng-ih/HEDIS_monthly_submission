# %% [markdown]
# # Member Compare Current Pull with Last Submission

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
file_name = 'Member'

path_prev = f'../../data/past_submission/HP_{file_name}_20210921.txt'
path_now = f'../../output/HP_{file_name}_20211104.txt'

dtype = {'memphone1':str}

df_prev = pd.read_csv(path_prev, sep='|', low_memory=False, dtype=dtype)
df = pd.read_csv(path_now, sep='|', low_memory=False, dtype=dtype)

# %%
print(df_prev.shape)

n = len(df_prev['memnbr'].unique())
print(f'{n} unique memnbr')

display(df_prev.head(3))
# Out:
# (12520, 32)
# 12497 unique memnbr
#         memnbr       memlname memfname memmname    memdob memgender  \
# 0  1A05CC7XY50        PUMILIA    FRANK        J  19330708         M
# 1  1A14RA9QG85         NGUYEN    TRINA      NaN  19560824         F
# 2  1A15GQ4GY59  PRESTON OWENS   NICOLE        M  19660907         F
#
#   subscribernbr  mcr_pbp         HICN  MRN             memaddr1 memaddr2  \
# 0   1A05CC7XY50        7  1A05CC7XY50  NaN      6727 TERRENO DR      NaN
# 1   1A14RA9QG85        9  1A14RA9QG85  NaN       212 MALCOLM DR      NaN
# 2   1A15GQ4GY59       11  1A15GQ4GY59  NaN  7356 FLOWERWOOD WAY      NaN
#
#    memaddr3         memcity memstate   memzip   memphone1  race  race_source  \
# 0       NaN  RANCHO MURIETA       CA  95683.0  9163542466   NaN          NaN
# 1       NaN        RICHMOND       CA  94801.0  5102299459   NaN          NaN
# 2       NaN      SACRAMENTO       CA  95831.0  9168263442   NaN          NaN
#
#    ethnicity  ethnicity_source spoken_language_s written_language_s  \
# 0        NaN               NaN               ENG                ENG
# 1        NaN               NaN               VIE                VIE
# 2        NaN               NaN               ENG                ENG
#
#    other_language_s  spoken_language  written_language  other_language  \
# 0               NaN              NaN               NaN             NaN
# 1               NaN              NaN               NaN             NaN
# 2               NaN              NaN               NaN             NaN
#
#    guardian_lname  guardian_fname  guardian_mname  mcr_snp_type  plan_employee
# 0             NaN             NaN             NaN           NaN            NaN
# 1             NaN             NaN             NaN           NaN            NaN
# 2             NaN             NaN             NaN           NaN            NaN

# %%
print(df.shape)

n = len(df['memnbr'].unique())
print(f'{n} unique memnbr')

display(df.head(3))
# Out:
# (6372, 32)
# 6185 unique memnbr
#         memnbr memlname memfname memmname    memdob memgender subscribernbr  \
# 0  1A05CC7XY50  PUMILIA    FRANK        J  19330708         M   1A05CC7XY50
# 1  1A15UE0GY89   PHUONG   JOHNNY      NaN  19521115         M   1A15UE0GY89
# 2  1A16G46QH85     PHAM   NGUYET        T  19490803         F   1A16G46QH85
#
#    mcr_pbp         HICN  MRN                memaddr1 memaddr2  memaddr3  \
# 0        7  1A05CC7XY50  NaN         6727 TERRENO DR      NaN       NaN
# 1        9  1A15UE0GY89  NaN     1254 24TH AVE APT 2      NaN       NaN
# 2        7  1A16G46QH85  NaN  43753 CAMERON HILLS DR      NaN       NaN
#
#           memcity memstate  memzip   memphone1  race  race_source  ethnicity  \
# 0  RANCHO MURIETA       CA   95683  9163542466   NaN          NaN        NaN
# 1   SAN FRANCISCO       CA   94122  7143835399   NaN          NaN        NaN
# 2         FREMONT       CA   94539  4085681562   NaN          NaN        NaN
#
#    ethnicity_source spoken_language_s written_language_s  other_language_s  \
# 0               NaN               ENG                ENG               NaN
# 1               NaN               CHI                CHI               NaN
# 2               NaN               ENG                ENG               NaN
#
#    spoken_language  written_language  other_language  guardian_lname  \
# 0              NaN               NaN             NaN             NaN
# 1              NaN               NaN             NaN             NaN
# 2              NaN               NaN             NaN             NaN
#
#    guardian_fname  guardian_mname  mcr_snp_type  plan_employee
# 0             NaN             NaN           NaN            NaN
# 1             NaN             NaN           NaN            NaN
# 2             NaN             NaN           NaN            NaN

# %%
df_inspect = df[['memnbr']].drop_duplicates()\
    .merge(df_prev[['memnbr']].drop_duplicates(), on='memnbr', how='left', indicator=True)

n = df_inspect.query('_merge == "left_only"')['memnbr'].count()
print(f'Current submission not found in previous submission: {n}')
# Out:
# Current submission not found in previous submission: 1

# %%
df_inspect['_merge'].value_counts()
# Out:
# both          6184
# left_only        1
# right_only       0
# Name: _merge, dtype: int64

# %%
df_inspect = df_prev[['memnbr']].drop_duplicates()\
    .merge(df[['memnbr']].drop_duplicates(), on='memnbr', how='left', indicator=True)

n = df_inspect.query('_merge == "left_only"')['memnbr'].count()
print(f'Current submission not found in previous submission: {n}')
# Out:
# Current submission not found in previous submission: 6313

# %%
df_inspect['_merge'].value_counts()
# Out:
# left_only     6313
# both          6184
# right_only       0
# Name: _merge, dtype: int64

# %%
df_inspect.query('_merge == "left_only"')
# Out:
#             memnbr     _merge
# 1      1A14RA9QG85  left_only
# 2      1A15GQ4GY59  left_only
# 4      1A15XG4NF83  left_only
# 10     1A70VR5FC07  left_only
# 11     1A73W36JU91  left_only
# ...            ...        ...
# 12485  9Y76A48JQ78  left_only
# 12487  9Y98DN4XP49  left_only
# 12489  9YD3U14KK99  left_only
# 12490  9YG2KN8VF28  left_only
# 12491  9YK3W31EX05  left_only
#
# [6313 rows x 2 columns]
